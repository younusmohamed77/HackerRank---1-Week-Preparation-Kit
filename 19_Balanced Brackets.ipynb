# %% [markdown]
# A bracket is considered to be any one of the following characters: (, ), {, }, [, or ].
#
# Two brackets are considered to be a matched pair if the an opening bracket (i.e., (, [, or {) occurs to the left of a closing bracket (i.e., ), ], or }) of the exact same type. There are three types of matched pairs of brackets: [], {}, and ().
#
# A matching pair of brackets is not balanced if the set of brackets it encloses are not matched. For example, {[(])} is not balanced because the contents in between { and } are not balanced. The pair of square brackets encloses a single, unbalanced opening bracket, (, and the pair of parentheses encloses a single, unbalanced closing square bracket, ].
#
# By this logic, we say a sequence of brackets is balanced if the following conditions are met:
#
# - It contains no unmatched brackets.
# - The subset of brackets enclosed within the confines of a matched pair of brackets is also a matched pair of brackets.
#
# Given n strings of brackets, determine whether each sequence of brackets is balanced. If a string is balanced, return YES. Otherwise, return NO.

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'isBalanced' function below.
#
# The function is expected to return a STRING.
# The function accepts STRING s as parameter.
#

def isBalanced(s):
    # Write your code here
    pass

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    t = int(input().strip())

    for t_itr in range(t):
        s = input()

        result = isBalanced(s)

        fptr.write(result + '\n')

    fptr.close()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 21
#      18     pass
#      20 if __name__ == '__main__':
# ---> 21     fptr = open(os.environ['OUTPUT_PATH'], 'w')
#      23     t = int(input().strip())
#      25     for t_itr in range(t):
#
# File <frozen os>:679, in __getitem__(self, key)
#
# KeyError: 'OUTPUT_PATH'

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'isBalanced' function below.
#
# The function is expected to return a STRING.
# The function accepts STRING s as parameter.
#

def isBalanced(s):
    # Write your code here
    pass

if __name__ == '__main__':
    t = int(input().strip())

    for t_itr in range(t):
        s = input()

        result = isBalanced(s)

        print(result)
# Out:
# 3
# {[()]}
# None
# {[(])}
# None
# {{[[(())]]}}
# None

# %%
def count_check(s, open_brackets, close_brackets):
    open_counter = 0
    close_counter = 0
    
    for bracket in s:
        # print(bracket)
        
        if bracket in open_brackets:
            open_counter += 1
            
        elif bracket in close_brackets:
            close_counter += 1
    
    # print(s)
    # print(open_counter, close_counter)
    
    if open_counter != close_counter:
        return False
    
    else:
        return True

def isBalanced(s):
    print(s)
    open_brackets = ['{', '[', '(']
    close_brackets = ['}', ']', ')']
    
    count = count_check(s, open_brackets, close_brackets)
    
    if not count:
        return 'NO'
    
    for i in range(len(s)):
        bracket = s[i]
        print(bracket)
        
        if bracket in close_brackets:
            if i == 0:
                return 'NO'

            bracket_index = close_brackets.index(bracket)
            print(bracket_index)
            print(len(s))
            
            if s[i - 1] == open_brackets[bracket_index]:
                if len(s) > 2:
                    s = s[:i - 1] + s[i + 1:]
                    print("Entered here")
                    isBalanced(s)
                    
#                 elif len(s) == 2:
#                     s = ''
#                     return 'YES'
                
#                 elif len(s) == 0:
#                     return 'YES'
            return 'YES'

# %%
result = isBalanced(s)
print(result)
# Out:
# {{[[(())]]}}
# {
# {
# [
# [
# (
# (
# )
# 2
# 12
# Entered here
# {{[[()]]}}
# {
# {
# [
# [
# (
# )
# 2
# 10
# Entered here
# {{[[]]}}
# {
# {
# [
# [
# ]
# 1
# 8
# Entered here
# {{[]}}
# {
# {
# [
# ]
# 1
# 6
# Entered here
# {{}}
# {
# {
# }
# 0
# 4
# Entered here
# {}
# {
# }
# 0
# 2
# YES

# %%
def count_check(s, open_brackets, close_brackets):
    open_counter = 0
    close_counter = 0
    
    for bracket in s:
        # print(bracket)
        
        if bracket in open_brackets:
            open_counter += 1
            
        elif bracket in close_brackets:
            close_counter += 1
    
    # print(s)
    # print(open_counter, close_counter)
    
    if open_counter != close_counter:
        return False
    
    else:
        return True

def isBalanced(s):
    #print(s)
    open_brackets = ['{', '[', '(']
    close_brackets = ['}', ']', ')']
    
    count = count_check(s, open_brackets, close_brackets)
    
    if not count:
        return 'NO'
    
    for i in range(len(s)):
        bracket = s[i]
        #print(bracket)
        
        if bracket in close_brackets:
            if i == 0:
                return 'NO'

            bracket_index = close_brackets.index(bracket)
            #print(bracket_index)
            #print(len(s))
            
            if s[i - 1] == open_brackets[bracket_index]:
                if len(s) > 2:
                    s = s[:i - 1] + s[i + 1:]
                    #print("Entered here")
                    isBalanced(s)
                    
#                 elif len(s) == 2:
#                     s = ''
#                     return 'YES'
                
#                 elif len(s) == 0:
#                     return 'YES'

            else:
                return 'NO'
            
            return 'YES'

# %%
if __name__ == '__main__':
    t = int(input().strip())

    for t_itr in range(t):
        s = input()

        result = isBalanced(s)

        print(result)
# Out:
# 3
# {[()]}
# YES
# {[(])}
# NO
# {{[[(())]]}}
# YES

# %%
# Chat GPT
def isBalanced(s):
    # open_brackets = ['{', '[', '(']
    # close_brackets = ['}', ']', ')']
    
    # Create a map for closing to opening brackets
    matching_brackets = {')': '(', ']': '[', '}': '{'}
    
    # Continuously replace balanced pairs with an empty string
    prev_length = -1
    while len(s) != prev_length:
        prev_length = len(s)
        for open_b, close_b in matching_brackets.items():
            s = s.replace(f'{close_b}{open_b}', '')

    # If the string is empty, all brackets were balanced
    return 'YES' if not s else 'NO'
